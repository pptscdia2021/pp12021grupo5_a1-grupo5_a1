# %% [markdown]
# **Presentacion Grupo 5 Aula 1**
#
# ---

# %% [markdown]
# La presentacion del trabajo se realizo a traves de la pagina web Genial.ly (https://genial.ly/es/)

# %% [markdown]
# El link de la presentacion es la siguiente: https://view.genial.ly/61a1771bb7a2270d79b8a29a/presentation-ispc-grupo-5-aula-1
#
# Adjuntamos prints de la presentacion

# %% [markdown]
# ![1-presentacion.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2- indice.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![3-equipo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![4- proyectos.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![5- sprint1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![6 - sprint1 actividades.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![7- sprint2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![8- sprint2 actividades.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![9 - sprint3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![10- sprint3 actividades.jpg](data:image/jpeg;base64,...)
